# %%
from pyspark.sql import SparkSession

# Initialize Spark session with Iceberg configurations
spark = SparkSession.builder \
  .appName("IcebergLocalDevelopment") \
  .config('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.6.1') \
  .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
  .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog") \
  .config("spark.sql.catalog.local.type", "hadoop") \
  .config("spark.sql.catalog.local.warehouse", "spark-warehouse/iceberg") \
  .getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 26/04/25 13:51:10 WARN Utils: Your hostname, DESKTOP-S3JB25M resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/25 13:51:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/mnt/c/Users/felip/www/university/eng-dados/projeto/.venv/lib/python3.13/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/felipe/.ivy2/cache
# The jars for the packages stored in: /home/felipe/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-7f30314d-bbf9-4227-852a-b119b04444c6;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.6.1 in central
# downloading https://repo1.maven.org/maven2/org/apache/iceberg/iceberg-spark-runtime-3.5_2.12/1.6.1/iceberg-spark-runtime-3.5_2.12-1.6.1.jar ...
# 	[SUCCESSFUL ] org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.6.1!iceberg-spark-runtime-3.5_2.12.jar (1821ms)
# :: resolution report :: resolve 760ms :: artifacts dl 1823ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.6.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   1   |   1   |   1   |   0   ||   1   |   1   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-7f30314d-bbf9-4227-852a-b119b04444c6
# 	confs: [default]
# 	1 artifacts copied, 0 already retrieved (40844kB/53ms)
# 26/04/25 13:51:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/25 13:51:16 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.255.255.254:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>IcebergLocalDevelopment</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql(
  """
  CREATE TABLE local.carro_iceberg (id INT, placa STRING) USING iceberg
  """
)
# Out:
# DataFrame[]

# %%
spark.sql("select * from local.carro_iceberg").show()
# Out:
# +---+-----+
# | id|placa|
# +---+-----+
# +---+-----+

# %%
spark.sql("INSERT INTO local.carro_iceberg VALUES (1, 'XYZ1J34'), (2, 'RLC5B93'), (3, 'ABV1V23')")
# Out:
# DataFrame[]

# %%
spark.sql("select * from local.carro_iceberg").show()
# Out:
# +---+-------+
# | id|  placa|
# +---+-------+
# |  1|XYZ1J34|
# |  2|RLC5B93|
# |  3|ABV1V23|
# +---+-------+

# %%
spark.sql(
    """
    alter table local.carro_iceberg add column marca STRING, modelo STRING, ano INT
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    select * from local.carro_iceberg
    """
).show()
# Out:
# +---+-------+-----+------+----+
# | id|  placa|marca|modelo| ano|
# +---+-------+-----+------+----+
# |  1|XYZ1J34| NULL|  NULL|NULL|
# |  2|RLC5B93| NULL|  NULL|NULL|
# |  3|ABV1V23| NULL|  NULL|NULL|
# +---+-------+-----+------+----+

# %%
spark.sql(
    """
    update local.carro_iceberg set marca = 'Renault', modelo = 'Sandero', ano = 2021 where id = 1
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    select * from local.carro_iceberg
    """
).show()
# Out:
# +---+-------+-------+-------+----+
# | id|  placa|  marca| modelo| ano|
# +---+-------+-------+-------+----+
# |  2|RLC5B93|   NULL|   NULL|NULL|
# |  3|ABV1V23|   NULL|   NULL|NULL|
# |  1|XYZ1J34|Renault|Sandero|2021|
# +---+-------+-------+-------+----+

# %%
spark.sql('update local.carro_iceberg set marca="GM", modelo="tracker", ano=2020 where id = 2')
# Out:
# DataFrame[]

# %%
spark.sql('update local.carro_iceberg set marca="Ford", modelo="EcoSport", ano=2022 where id = 3')
# Out:
# DataFrame[]

# %%
spark.sql('select * from local.carro_iceberg').show()
# Out:
# +---+-------+-------+--------+----+
# | id|  placa|  marca|  modelo| ano|
# +---+-------+-------+--------+----+
# |  2|RLC5B93|     GM| tracker|2020|
# |  3|ABV1V23|   Ford|EcoSport|2022|
# |  1|XYZ1J34|Renault| Sandero|2021|
# +---+-------+-------+--------+----+

# %%
spark.sql('delete from local.carro_iceberg where id = 3')
# Out:
# DataFrame[]

# %%
spark.sql('select * from local.carro_iceberg').show()
# Out:
# +---+-------+-------+-------+----+
# | id|  placa|  marca| modelo| ano|
# +---+-------+-------+-------+----+
# |  2|RLC5B93|     GM|tracker|2020|
# |  1|XYZ1J34|Renault|Sandero|2021|
# +---+-------+-------+-------+----+
